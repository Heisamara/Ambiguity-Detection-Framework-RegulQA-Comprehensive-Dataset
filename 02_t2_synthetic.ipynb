# %% [markdown]
# # 02 – T2 Synthetic (with sector tokens)

# %%
# !pip install pandas pyyaml
from pathlib import Path
ROOT = Path.cwd().resolve().parents[1] if (Path.cwd().name=='notebooks') else Path.cwd()
print('ROOT =', ROOT)
# Out:
# ROOT = /Users/amarachi/Documents/AQA/Dataset_T1

# %%
import importlib.util
def _load(path, name):
    spec = importlib.util.spec_from_file_location(name, path)
    mod = importlib.util.module_from_spec(spec); spec.loader.exec_module(mod); return mod
synth = _load(ROOT/'/Users/amarachi/Documents/AQA/Dataset_T1/RegulQA-Phase1/src/data/synth_t2.py','synth_t2')
synth.make_synthetic(n_each=100)
# Out:
# Synthetic → /Users/amarachi/Documents/AQA/Dataset_T1/RegulQA-Phase1/data/raw/t2_synthetic/synthetic_requirements.csv rows: 300

# %%
cln = _load(ROOT/'/Users/amarachi/Documents/AQA/Dataset_T1/RegulQA-Phase1/src/data/clean_all.py','clean_all')
df = cln.build_pool()
df[['id','source','tier','sector','document','req_text']].tail(10)
# Out:
# Wrote /Users/amarachi/Documents/AQA/Dataset_T1/RegulQA-Phase1/data/processed/regulqa_ambig_pool.csv rows: 280
#              id     source tier     sector                    document  \
# 270  SYN_000270  SYNTHETIC   T2  aerospace  synthetic_requirements.csv
# 271  SYN_000271  SYNTHETIC   T2  aerospace  synthetic_requirements.csv
# 272  SYN_000272  SYNTHETIC   T2  aerospace  synthetic_requirements.csv
# 273  SYN_000273  SYNTHETIC   T2  aerospace  synthetic_requirements.csv
# 274  SYN_000274  SYNTHETIC   T2  aerospace  synthetic_requirements.csv
# 275  SYN_000275  SYNTHETIC   T2  aerospace  synthetic_requirements.csv
# 276  SYN_000276  SYNTHETIC   T2  aerospace  synthetic_requirements.csv
# 277  SYN_000277  SYNTHETIC   T2  aerospace  synthetic_requirements.csv
# 278  SYN_000278  SYNTHETIC   T2  aerospace  synthetic_requirements.csv
# 279  SYN_000279  SYNTHETIC   T2  aerospace  synthetic_requirements.csv
#
#                                               req_text
# ...
