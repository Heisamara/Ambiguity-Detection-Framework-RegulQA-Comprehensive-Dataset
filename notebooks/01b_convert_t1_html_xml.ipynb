# %% [markdown]
# # 01b – Convert T1 HTML/XML → CSV

# %%
# !pip install beautifulsoup4 lxml pandas
from pathlib import Path
ROOT = Path.cwd().resolve().parents[1] if (Path.cwd().name=='notebooks') else Path.cwd()
print('ROOT =', ROOT)
# Out:
# ROOT = /Users/amarachi/Documents/AQA/Dataset_T1

# %%
import importlib.util
def _load(path, name):
    spec = importlib.util.spec_from_file_location(name, path)
    mod = importlib.util.module_from_spec(spec); spec.loader.exec_module(mod); return mod
conv = _load(ROOT/'/Users/amarachi/Documents/AQA/Dataset_T1/RegulQA-Phase1/src/data/convert_t1_html_xml.py', 'convert_t1_html_xml')
conv.convert_all()
# Out:
# Converted: 2007-ertms.xml → 2007-ertms.csv
# Converted: 2007 - get real 0.2.xml → 2007 - get real 0.2.csv
# Converted: 1998 - themas.xml → 1998 - themas.csv
# Converted: 2008 - keepass.xml → 2008 - keepass.csv
# Converted: 0000 - gamma j.xml → 0000 - gamma j.csv
# Converted: 2009 - video search.xml → 2009 - video search.csv
# Converted: 2009 - peppol approved.xml → 2009 - peppol approved.csv
# Converted: 2007-eirene_fun_7-2.xml → 2007-eirene_fun_7-2.csv
# Converted: 0000 - cctns.xml → 0000 - cctns.csv
# Converted: 1995 - gemini.xml → 1995 - gemini.csv
# Converted: 2003 - qheadache.xml → 2003 - qheadache.csv
# Converted: 2006 - eirene sys 15.xml → 2006 - eirene sys 15.csv
# Converted: 2005 - phin.xml → 2005 - phin.csv
# Converted: 2010-blitdraft.xml → 2010-blitdraft.csv
# Converted: 2005 - microcare.xml → 2005 - microcare.csv
# Converted: 1999 - dii.xml → 1999 - dii.csv
# Converted: 1999 - tcs.xml → 1999 - tcs.csv
# Done. CSVs: 17
# ...

# %% [markdown]
# Run this after you place any T1 **.html/.xml** files under `data/raw/t1_*`. Converted CSVs are created next to originals.
