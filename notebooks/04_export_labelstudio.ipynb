# %% [markdown]
# # 04 – Export for Label Studio
# Unifies all tiers into one CSV and gives instructions for import.

# %%
from pathlib import Path
import pandas as pd, json
ROOT = Path.cwd().resolve().parents[1] if (Path.cwd().name=='notebooks') else Path.cwd()
df = pd.read_csv(ROOT/'data/processed/regulqa_ambig_pool.csv')
print(df.shape)
df.head(5)

# %% [markdown]
# **Import tips (Label Studio):**
# - Project → Labeling setup → **Upload** config from `annotation/labelstudio/regulqa_label_config.xml`
# - Import data → Choose **CSV** → select `data/processed/regulqa_ambig_pool.csv`
# - Map fields: `req_text` → Text; others are stored as attributes.
